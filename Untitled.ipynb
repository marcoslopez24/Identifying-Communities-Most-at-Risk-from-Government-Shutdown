# %% [raw]
# ##We will collect data from the USDA Food Access Research Atlas, the USDA SNAP Participation dataset, and the 2019 ACS 5-year estimates. From these sources we will extract six variables that measure income, poverty, SNAP reliance, and food access conditions. After cleaning the data and standardizing county identifiers using FIPS codes, we will merge all sources into a single county-level dataset. We will then group counties by income or poverty level and calculate average SNAP participation and food desert indicators for each group.
# Our analysis will examine how income, poverty, food access, and SNAP dependence relate to one another in order to identify whether lower-income or higher-SNAP-reliance counties face greater structural vulnerability. Simple visualizations, such as scatterplots, bar charts, and maps, will highlight differences across county groups and reveal where food access barriers are most concentrated. If counties with lower income and higher SNAP participation also show greater food desert prevalence or limited grocery access, the results will support the hypothesis that these communities are at increased risk during government shutdowns when federal nutrition benefits may be delayed or interrupted.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./2019 Food Access Research Atlas Data/Food Access Research Atlas.csv")

# %%
df
# Out:
#        CensusTract    State           County  Urban  Pop2010  OHU2010  \
# 0       1001020100  Alabama   Autauga County      1     1912      693
# 1       1001020200  Alabama   Autauga County      1     2170      743
# 2       1001020300  Alabama   Autauga County      1     3373     1256
# 3       1001020400  Alabama   Autauga County      1     4386     1722
# 4       1001020500  Alabama   Autauga County      1    10766     4082
# ...            ...      ...              ...    ...      ...      ...
# 72526  56043000200  Wyoming  Washakie County      0     3326     1317
# 72527  56043000301  Wyoming  Washakie County      1     2665     1154
# 72528  56043000302  Wyoming  Washakie County      1     2542     1021
# 72529  56045951100  Wyoming    Weston County      0     3314     1322
# 72530  56045951300  Wyoming    Weston County      1     3894     1699
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# ...

# %%
df2 = pd.read_excel("Jan 2019.xls", header=2)

# remove empty rows
df2 = df2.dropna(how="all")

# remove empty columns
df2 = df2.dropna(axis=1, how="all")

df2 = df2[df2.iloc[:,0].notna()]

df2.reset_index(drop=True, inplace=True)

df2.head()
# Out:
#                            Jan 2019  \
# 0                   Substate/Region
# 1  0100101 AL EBT AUTAUGA CO FS OFF
# 2  0100301 AL EBT BALDWIN CO FS OFF
# 3  0100501 AL EBT BARBOUR CO FS OFF
# 4     0100701 AL EBT BIBB CO FS OFF
#
#                                          Unnamed: 1  \
# 0  SNAP All Persons Public Assistance Participation
# 1                                               958
# 2                                              1897
# 3                                               832
# 4                                               503
#
#                                           Unnamed: 3  \
# 0  SNAP All Persons Non-Public Assistance Partici...
# 1                                               6501
# 2                                              18484
# 3                                               5116
# 4                                               2666
#
#                               Unnamed: 5  \
# 0  Calc: SNAP Total PA and Non-PA People
# ...
